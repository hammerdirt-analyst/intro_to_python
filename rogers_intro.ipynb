# %% [markdown]
# ### The intro notebook learn python
#
# #### use this to get started
#
# 1)   create copies on your branch with your name in the file name
#
# 2)   make sure to include the subject in the file name

# %%
import numpy as np
import json
import requests

# %%
# get some data using the request library
# https://requests.readthedocs.io/en/master/

survey_data = requests.get('https://mwshovel.pythonanywhere.com/api/surveys/survey-results/?location__country=CH&date=2018-01-01')
beach_data = requests.get('https://mwshovel.pythonanywhere.com/api/list-of-beaches/swiss/')

survey_data = survey_data.json()
beach_data = beach_data.json()

# %%
beach_data
# Out:
# [{'slug': 'aarezufluss_bern_scheurerk',
#   'location': 'aarezufluss_bern_scheurerk',
#   'latitude': '46.97100970',
#   'longitude': '7.45278970',
#   'city': 'Bern',
#   'post': '3004',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Aare',
#   'city_slug': 'bern',
#   'water_name_slug': 'aare',
#   'is_2020': False},
#  {'slug': 'aare_bern_caveltin',
#   'location': 'Aare_Bern_CaveltiN',
#   'latitude': '46.92357880',
#   'longitude': '7.47331910',
#   'city': 'Muri bei Bern',
#   'post': '3074',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Aare',
#   'city_slug': 'muri-bei-bern',
#   'water_name_slug': 'aare',
#   'is_2020': False},
#  {'slug': 'aare_bern_gerberm',
#   'location': 'Aare_bern_gerberm',
#   'latitude': '46.98936310',
#   'longitude': '7.45209770',
#   'city': 'Bern',
#   'post': '3004',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Aare',
#   'city_slug': 'bern',
#   'water_name_slug': 'aare',
#   'is_2020': False},
#  {'slug': 'aare_bern_scheurerk',
#   'location': 'aare_bern_scheurerk',
#   'latitude': '46.97096720',
#   'longitude': '7.45258570',
#   'city': 'Bern',
#   'post': '3004',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Aare',
#   'city_slug': 'bern',
#   'water_name_slug': 'aare',
#   'is_2020': False},
#  {'slug': 'aare_brugg_buchie',
#   'location': 'Aare_Brugg_BuchiE',
#   'latitude': '47.49485530',
#   'longitude': '8.23655810',
#   'city': 'Brugg',
#   'post': '5200',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Aare',
#   'city_slug': 'brugg',
#   'water_name_slug': 'aare',
#   'is_2020': False},
#  {'slug': 'aare_elfenau_cataldiv',
#   'location': 'Aare_Elfenau_cataldiv',
#   'latitude': '46.93102010',
#   'longitude': '7.46296050',
#   'city': 'Bern',
#   'post': '3006',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Aare',
#   'city_slug': 'bern',
#   'water_name_slug': 'aare',
#   'is_2020': False},
#  {'slug': 'aare_kehrsatz_stolten',
#   'location': 'aare_kehrsatz_stolten',
#   'latitude': '46.92357190',
#   'longitude': '7.48830110',
#   'city': 'Belp',
#   'post': '3123',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Aare',
#   'city_slug': 'belp',
#   'water_name_slug': 'aare',
#   'is_2020': False},
#  {'slug': 'aare_koniz_hoppej',
#   'location': 'aare_köniz_hoppej',
#   'latitude': '46.93458850',
#   'longitude': '7.45817030',
#   'city': 'Köniz',
#   'post': '3084',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Aare',
#   'city_slug': 'koniz',
#   'water_name_slug': 'aare',
#   'is_2020': False},
#  {'slug': 'aare_rupperswil_badert',
#   'location': 'aare_rupperswil_badert',
#   'latitude': '47.41030900',
#   'longitude': '8.11255370',
#   'city': 'Rupperswil',
#   'post': '5102',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Aare',
#   'city_slug': 'rupperswil',
#   'water_name_slug': 'aare',
#   'is_2020': False},
#  {'slug': 'aare_solothurn_nguyena',
#   'location': 'aare_solothurn_nguyena',
#   'latitude': '47.19774950',
#   'longitude': '7.52422470',
#   'city': 'Solothurn',
#   'post': '4500',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Aare',
#   'city_slug': 'solothurn',
#   'water_name_slug': 'aare',
#   'is_2020': False},
#  {'slug': 'aare_suhrespitz_badert',
#   'location': 'aare_suhrespitz_badert',
#   'latitude': '47.40566920',
#   'longitude': '8.06601800',
#   'city': 'Aarau',
#   'post': '5032',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Aare',
#   'city_slug': 'aarau',
#   'water_name_slug': 'aare',
#   'is_2020': False},
#  {'slug': 'anarchy-beach',
#   'location': 'Anarchy Beach',
#   'latitude': '46.44721600',
#   'longitude': '6.85961200',
#   'city': 'La Tour de Peilz',
#   'post': '1814',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'la-tour-de-peilz',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'arabie',
#   'location': 'Arabie',
#   'latitude': '46.46209900',
#   'longitude': '6.83497200',
#   'city': 'Vevey',
#   'post': '1800',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'vevey',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'arve_carouge_battistellak',
#   'location': 'arve_carouge_battistellak',
#   'latitude': '46.17849120',
#   'longitude': '6.15431870',
#   'city': 'Veyrier',
#   'post': '1234',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Arve',
#   'city_slug': 'veyrier',
#   'water_name_slug': 'arve',
#   'is_2020': False},
#  {'slug': 'baby-plage-geneva',
#   'location': 'Baby Plage Geneva',
#   'latitude': '46.20855800',
#   'longitude': '6.16292300',
#   'city': 'Genève',
#   'post': '1208',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'geneve',
#   'water_name_slug': 'lac-leman',
#   'is_2020': True},
#  {'slug': 'bagno-pubblico-ascona',
#   'location': 'Bagno Pubblico Ascona',
#   'latitude': '46.14756500',
#   'longitude': '8.77914400',
#   'city': 'Ascona',
#   'post': '6612',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lago Maggiore',
#   'city_slug': 'ascona',
#   'water_name_slug': 'lago-maggiore',
#   'is_2020': True},
#  {'slug': 'bain-des-dames',
#   'location': 'Bain des Dames',
#   'latitude': '46.45050680',
#   'longitude': '6.85809180',
#   'city': 'La Tour de Peilz',
#   'post': '1814',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'la-tour-de-peilz',
#   'water_name_slug': 'lac-leman',
#   'is_2020': True},
#  {'slug': 'baye-de-clarens',
#   'location': 'Baye de Clarens',
#   'latitude': '46.43978700',
#   'longitude': '6.88890300',
#   'city': 'Montreux',
#   'post': '1815',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'montreux',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'baye-de-montreux-d',
#   'location': 'Baye de Montreux D',
#   'latitude': '46.43096200',
#   'longitude': '6.90867300',
#   'city': 'Montreux',
#   'post': '1820',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'montreux',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'baye-de-montreux-g',
#   'location': 'Baye de Montreux G',
#   'latitude': '46.43083400',
#   'longitude': '6.90877800',
#   'city': 'Montreux',
#   'post': '1820',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'montreux',
#   'water_name_slug': 'lac-leman',
#   'is_2020': True},
#  {'slug': 'berlingen-swisslitterreport',
#   'location': 'Berlingen swisslitterreport',
#   'latitude': '47.67243120',
#   'longitude': '9.01105530',
#   'city': 'Berlingen',
#   'post': '8267',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Untersee',
#   'city_slug': 'berlingen',
#   'water_name_slug': 'untersee',
#   'is_2020': False},
#  {'slug': 'bielersee_vinelz_fankhausers',
#   'location': 'Bielersee_Vinelz_FankhauserS',
#   'latitude': '47.03839840',
#   'longitude': '7.10831140',
#   'city': 'Vinelz',
#   'post': '3234',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Bielersee',
#   'city_slug': 'vinelz',
#   'water_name_slug': 'bielersee',
#   'is_2020': True},
#  {'slug': 'birskopfli-rusco',
#   'location': 'Birsköpfli Rusco',
#   'latitude': '47.55774290',
#   'longitude': '7.61729160',
#   'city': 'Birsfelden',
#   'post': '4127',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Birs',
#   'city_slug': 'birsfelden',
#   'water_name_slug': 'birs',
#   'is_2020': False},
#  {'slug': 'birs_basel_grunern',
#   'location': 'Birs_Basel_GrunerN',
#   'latitude': '47.55112760',
#   'longitude': '7.62219880',
#   'city': 'Basel',
#   'post': '4052',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Birs',
#   'city_slug': 'basel',
#   'water_name_slug': 'birs',
#   'is_2020': False},
#  {'slug': 'birs_basel_laderachs',
#   'location': 'Birs_basel_lÃ¤derachs',
#   'latitude': '47.54604970',
#   'longitude': '7.62259810',
#   'city': 'Basel',
#   'post': '4052',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Birs',
#   'city_slug': 'basel',
#   'water_name_slug': 'birs',
#   'is_2020': False},
#  {'slug': 'birs_reinach_dinuccin',
#   'location': 'Birs_Reinach_DiNucciN',
#   'latitude': '47.50368170',
#   'longitude': '7.60700850',
#   'city': 'Reinach',
#   'post': '4153',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Birs',
#   'city_slug': 'reinach',
#   'water_name_slug': 'birs',
#   'is_2020': False},
#  {'slug': 'bodensee_altenrhein_caluoria',
#   'location': 'bodensee_altenrhein_caluoria',
#   'latitude': '47.48650690',
#   'longitude': '9.54396640',
#   'city': 'Thal',
#   'post': '9422',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Bodensee',
#   'city_slug': 'thal',
#   'water_name_slug': 'bodensee',
#   'is_2020': False},
#  {'slug': 'bodensee_arbon_moslis',
#   'location': 'Bodensee_Arbon_MosliS',
#   'latitude': '47.52088870',
#   'longitude': '9.43114400',
#   'city': 'Arbon',
#   'post': '9320',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Bodensee',
#   'city_slug': 'arbon',
#   'water_name_slug': 'bodensee',
#   'is_2020': False},
#  {'slug': 'bodensee_horn_huberm',
#   'location': 'bodensee_horn_huberm',
#   'latitude': '47.49827570',
#   'longitude': '9.45697820',
#   'city': 'Horn',
#   'post': '9326',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Bodensee',
#   'city_slug': 'horn',
#   'water_name_slug': 'bodensee',
#   'is_2020': False},
#  {'slug': 'bodensee_steinach_dolder_a',
#   'location': 'Bodensee_Steinach_Dolder_A',
#   'latitude': '47.50629920',
#   'longitude': '9.43617140',
#   'city': 'Steinach',
#   'post': '9323',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Bodensee',
#   'city_slug': 'steinach',
#   'water_name_slug': 'bodensee',
#   'is_2020': False},
#  {'slug': 'bodensee_thal_schlachterj_1',
#   'location': 'bodensee_thal_schlachterj_1',
#   'latitude': '47.48621630',
#   'longitude': '9.54390990',
#   'city': 'Thal',
#   'post': '9422',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Bodensee',
#   'city_slug': 'thal',
#   'water_name_slug': 'bodensee',
#   'is_2020': False},
#  {'slug': 'boiron',
#   'location': 'Boiron',
#   'latitude': '46.49102970',
#   'longitude': '6.48016180',
#   'city': 'Tolochenaz',
#   'post': '1131',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'tolochenaz',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'chriesbach_duebendorf_schneidera',
#   'location': 'chriesbach_duebendorf_schneidera',
#   'latitude': '47.40291950',
#   'longitude': '8.60514580',
#   'city': 'Dübendorf',
#   'post': '8600',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Chriesbach',
#   'city_slug': 'dubendorf',
#   'water_name_slug': 'chriesbach',
#   'is_2020': False},
#  {'slug': 'emme_biberist_jennim',
#   'location': 'emme_biberist_jennim',
#   'latitude': '47.16922080',
#   'longitude': '7.55899480',
#   'city': 'Biberist',
#   'post': '4562',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Emme',
#   'city_slug': 'biberist',
#   'water_name_slug': 'emme',
#   'is_2020': False},
#  {'slug': 'emme_luterbach_huggenbergerk',
#   'location': 'emme_luterbach_huggenbergerk',
#   'latitude': '47.21194420',
#   'longitude': '7.57401440',
#   'city': 'Zuchwil',
#   'post': '4528',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Emme',
#   'city_slug': 'zuchwil',
#   'water_name_slug': 'emme',
#   'is_2020': False},
#  {'slug': 'emme_utzenstorf_gruttert',
#   'location': 'Emme_Utzenstorf_Grüttert',
#   'latitude': '47.12369600',
#   'longitude': '7.53962700',
#   'city': 'Utzenstorf',
#   'post': '3427',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Emme',
#   'city_slug': 'utzenstorf',
#   'water_name_slug': 'emme',
#   'is_2020': False},
#  {'slug': 'evole-plage',
#   'location': 'Evole plage',
#   'latitude': '46.98947700',
#   'longitude': '6.92392000',
#   'city': 'Neuchâtel',
#   'post': '2000',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Neuenburgersee',
#   'city_slug': 'neuchatel',
#   'water_name_slug': 'neuenburgersee',
#   'is_2020': True},
#  {'slug': 'glatt_oerlikon_covosn',
#   'location': 'glatt_oerlikon_covosN',
#   'latitude': '47.41676910',
#   'longitude': '8.56671200',
#   'city': 'Opfikon',
#   'post': '8152',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Glatt',
#   'city_slug': 'opfikon',
#   'water_name_slug': 'glatt',
#   'is_2020': False},
#  {'slug': 'goldach_goldach_schlachterj',
#   'location': 'goldach_goldach_schlachterj',
#   'latitude': '47.47391110',
#   'longitude': '9.45930940',
#   'city': 'Goldach',
#   'post': '9403',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Goldach',
#   'city_slug': 'goldach',
#   'water_name_slug': 'goldach',
#   'is_2020': False},
#  {'slug': 'grand-clos',
#   'location': 'Grand Clos',
#   'latitude': '46.38774600',
#   'longitude': '6.84368600',
#   'city': 'Saint Gingolph',
#   'post': '1898',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'saint-gingolph',
#   'water_name_slug': 'lac-leman',
#   'is_2020': True},
#  {'slug': 'greifensee_fallanden_meistery',
#   'location': 'greifensee_fällanden_meistery',
#   'latitude': '47.36093810',
#   'longitude': '8.65372280',
#   'city': 'Fällanden',
#   'post': '8117',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Greifensee',
#   'city_slug': 'fallanden',
#   'water_name_slug': 'greifensee',
#   'is_2020': False},
#  {'slug': 'greifensee_fallanden_simmenc',
#   'location': 'greifensee_fällanden_simmenc',
#   'latitude': '47.35971410',
#   'longitude': '8.65484330',
#   'city': 'Fällanden',
#   'post': '8117',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Greifensee',
#   'city_slug': 'fallanden',
#   'water_name_slug': 'greifensee',
#   'is_2020': False},
#  {'slug': 'greifensee_greifensee_simmenc',
#   'location': 'greifensee_greifensee_simmenc',
#   'latitude': '47.36357230',
#   'longitude': '8.67569910',
#   'city': 'Greifensee',
#   'post': '8606',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Greifensee',
#   'city_slug': 'greifensee',
#   'water_name_slug': 'greifensee',
#   'is_2020': False},
#  {'slug': 'greifensee_maur_simmenc',
#   'location': 'greifensee_maur_simmenc',
#   'latitude': '47.33238640',
#   'longitude': '8.68551460',
#   'city': 'Maur',
#   'post': '8124',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Greifensee',
#   'city_slug': 'maur',
#   'water_name_slug': 'greifensee',
#   'is_2020': False},
#  {'slug': 'greifensee_uster_fischerb_-2',
#   'location': 'greifensee_uster_fischerb_ 2',
#   'latitude': '47.34743600',
#   'longitude': '8.68988050',
#   'city': 'Uster',
#   'post': '8610',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Greifensee',
#   'city_slug': 'uster',
#   'water_name_slug': 'greifensee',
#   'is_2020': False},
#  {'slug': 'greifensee_uster_fischerb_1',
#   'location': 'greifensee_uster_fischerb_1',
#   'latitude': '47.35012740',
#   'longitude': '8.68979720',
#   'city': 'Uster',
#   'post': '8610',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Greifensee',
#   'city_slug': 'uster',
#   'water_name_slug': 'greifensee',
#   'is_2020': False},
#  {'slug': 'grendelbach_effretikon_dambonec',
#   'location': 'Grendelbach_Effretikon_DamboneC',
#   'latitude': '47.42564910',
#   'longitude': '8.69070620',
#   'city': 'Illnau Effretikon',
#   'post': '8307',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Grändelbach',
#   'city_slug': 'illnau-effretikon',
#   'water_name_slug': 'grandelbach',
#   'is_2020': False},
#  {'slug': 'gasi-strand',
#   'location': 'Gäsi Strand',
#   'latitude': '47.12844200',
#   'longitude': '9.11083100',
#   'city': 'Weesen',
#   'post': '8872',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Walensee',
#   'city_slug': 'weesen',
#   'water_name_slug': 'walensee',
#   'is_2020': True},
#  {'slug': 'inn_pradella_kohlt',
#   'location': 'Inn_Pradella_KohlT',
#   'latitude': '46.80087600',
#   'longitude': '10.31999400',
#   'city': 'Scuol',
#   'post': '7550',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Inn',
#   'city_slug': 'scuol',
#   'water_name_slug': 'inn',
#   'is_2020': False},
#  {'slug': 'jardin-botanique',
#   'location': 'Jardin Botanique',
#   'latitude': '46.22590880',
#   'longitude': '6.14935720',
#   'city': 'Genève',
#   'post': '1202',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'geneve',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'jona_tann_nusslin',
#   'location': 'jona_tann_nusslin',
#   'latitude': '47.26842720',
#   'longitude': '8.86412510',
#   'city': 'Dürnten',
#   'post': '8635',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Jona',
#   'city_slug': 'durnten',
#   'water_name_slug': 'jona',
#   'is_2020': False},
#  {'slug': 'katzenbach_zuerich_sanesim',
#   'location': 'katzenbach_zuerich_sanesim',
#   'latitude': '47.42847280',
#   'longitude': '8.51308800',
#   'city': 'Zurich',
#   'post': '8046',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Katzensee',
#   'city_slug': 'zurich',
#   'water_name_slug': 'katzensee',
#   'is_2020': False},
#  {'slug': 'katzensee_regensdorfzuerichaffoltern_stueberj',
#   'location': 'katzensee_regensdorfzuerichaffoltern_stueberj',
#   'latitude': '47.43112810',
#   'longitude': '8.49292430',
#   'city': 'Zurich',
#   'post': '8046',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Katzensee',
#   'city_slug': 'zurich',
#   'water_name_slug': 'katzensee',
#   'is_2020': False},
#  {'slug': 'la-morges',
#   'location': 'La Morges',
#   'latitude': '46.50406300',
#   'longitude': '6.49409900',
#   'city': 'Morges',
#   'post': '1110',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'morges',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'la-petite-plage',
#   'location': 'La Petite plage',
#   'latitude': '46.78505400',
#   'longitude': '6.65687700',
#   'city': 'Yverdon-les-Bains',
#   'post': '1400',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Neuenburgersee',
#   'city_slug': 'yverdon-les-bains',
#   'water_name_slug': 'neuenburgersee',
#   'is_2020': True},
#  {'slug': 'lac-leman-hammerdirt',
#   'location': 'Lac Léman Hammerdirt',
#   'latitude': '46.45038920',
#   'longitude': '6.85823420',
#   'city': 'La Tour de Peilz',
#   'post': '1814',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'la-tour-de-peilz',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'lacleman_gland_kubela',
#   'location': 'lacléman_gland_kubela',
#   'latitude': '46.40286930',
#   'longitude': '6.28193580',
#   'city': 'Gland',
#   'post': '1196',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'gland',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'lacleman_gland_lecoanets',
#   'location': 'Lacléman_Gland_LecoanetS',
#   'latitude': '46.40281060',
#   'longitude': '6.28195860',
#   'city': 'Gland',
#   'post': '1196',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'gland',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'lacleman_vidy_santie',
#   'location': 'lacléman_vidy_santie',
#   'latitude': '46.51831780',
#   'longitude': '6.58960780',
#   'city': 'Lausanne',
#   'post': '1007',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'lausanne',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'langete_langenthal_geiserm',
#   'location': 'langete_langenthal_geiserm',
#   'latitude': '47.21653320',
#   'longitude': '7.79230410',
#   'city': 'Langenthal',
#   'post': '4900',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Langeten',
#   'city_slug': 'langenthal',
#   'water_name_slug': 'langeten',
#   'is_2020': False},
#  {'slug': 'le-pierrier',
#   'location': 'Le Pierrier',
#   'latitude': '46.43972700',
#   'longitude': '6.88896800',
#   'city': 'Montreux',
#   'post': '1815',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'montreux',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'le-port',
#   'location': 'Le Port',
#   'latitude': '46.45224500',
#   'longitude': '6.85518000',
#   'city': 'La Tour de Peilz',
#   'post': '1814',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'la-tour-de-peilz',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'limmat_dietikon_keiserp',
#   'location': 'limmat_dietikon_keiserp',
#   'latitude': '47.40798910',
#   'longitude': '8.40953980',
#   'city': 'Dietikon',
#   'post': '8953',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Limmat',
#   'city_slug': 'dietikon',
#   'water_name_slug': 'limmat',
#   'is_2020': False},
#  {'slug': 'limmat_unterengstringen_oggierbuhrer',
#   'location': 'Limmat_Unterengstringen_OggierBührer',
#   'latitude': '47.40940030',
#   'longitude': '8.44693340',
#   'city': 'Unterengstringen',
#   'post': '8103',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Limmat',
#   'city_slug': 'unterengstringen',
#   'water_name_slug': 'limmat',
#   'is_2020': False},
#  {'slug': 'limmat_zuerich_jansena',
#   'location': 'Limmat_Zuerich_JansenA',
#   'latitude': '47.40002470',
#   'longitude': '8.48468470',
#   'city': 'Zurich',
#   'post': '8064',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Limmat',
#   'city_slug': 'zurich',
#   'water_name_slug': 'limmat',
#   'is_2020': False},
#  {'slug': 'limmat_zuerich_suterdglauserp',
#   'location': 'limmat_zuerich_suterd&glauserp',
#   'latitude': '47.39453930',
#   'longitude': '8.51344350',
#   'city': 'Zurich',
#   'post': '8005',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Limmat',
#   'city_slug': 'zurich',
#   'water_name_slug': 'limmat',
#   'is_2020': False},
#  {'slug': 'limmat_zuerich_wagnerc',
#   'location': 'Limmat_Zuerich_WagnerC',
#   'latitude': '47.40349560',
#   'longitude': '8.47777010',
#   'city': 'Zurich',
#   'post': '8064',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Limmat',
#   'city_slug': 'zurich',
#   'water_name_slug': 'limmat',
#   'is_2020': False},
#  {'slug': 'limmat_zurich_mortensena_meiera',
#   'location': 'limmat_zürich_mortensena_meiera',
#   'latitude': '47.40025150',
#   'longitude': '8.48541100',
#   'city': 'Zurich',
#   'post': '8064',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Limmat',
#   'city_slug': 'zurich',
#   'water_name_slug': 'limmat',
#   'is_2020': False},
#  {'slug': 'lorze_baar_blarere',
#   'location': 'Lorze_Baar_BlarerE',
#   'latitude': '47.19540190',
#   'longitude': '8.54023700',
#   'city': 'Baar',
#   'post': '6340',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Lorze',
#   'city_slug': 'baar',
#   'water_name_slug': 'lorze',
#   'is_2020': False},
#  {'slug': 'lotschebach_bern_scheurerk',
#   'location': 'lötschebach_bern_scheurerk',
#   'latitude': '46.96494600',
#   'longitude': '7.49283590',
#   'city': 'Ostermundigen',
#   'post': '3072',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Lötschebach',
#   'city_slug': 'ostermundigen',
#   'water_name_slug': 'lotschebach',
#   'is_2020': False},
#  {'slug': 'maladaire',
#   'location': 'Maladaire',
#   'latitude': '46.44629600',
#   'longitude': '6.87696000',
#   'city': 'La Tour de Peilz',
#   'post': '1814',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'la-tour-de-peilz',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'mammern-swisslitterreport',
#   'location': 'Mammern swisslitterreport',
#   'latitude': '47.65583660',
#   'longitude': '8.95531680',
#   'city': 'Steckborn',
#   'post': '8266',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Untersee',
#   'city_slug': 'steckborn',
#   'water_name_slug': 'untersee',
#   'is_2020': False},
#  {'slug': 'murg_waengi_strickerr',
#   'location': 'Murg_Waengi_StrickerR',
#   'latitude': '47.49361000',
#   'longitude': '8.96159280',
#   'city': 'Wängi',
#   'post': '9545',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Murg',
#   'city_slug': 'wangi',
#   'water_name_slug': 'murg',
#   'is_2020': False},
#  {'slug': 'mullermatte',
#   'location': 'Müllermatte',
#   'latitude': '47.13333900',
#   'longitude': '7.22790700',
#   'city': 'biel',
#   'post': '2505',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Bielersee',
#   'city_slug': 'biel',
#   'water_name_slug': 'bielersee',
#   'is_2020': True},
#  {'slug': 'neuenburgersee_cudrefin_mattera',
#   'location': 'Neuenburgersee_Cudrefin_MatterA',
#   'latitude': '46.96270890',
#   'longitude': '7.02596810',
#   'city': 'Cudrefin',
#   'post': '1588',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Neuenburgersee',
#   'city_slug': 'cudrefin',
#   'water_name_slug': 'neuenburgersee',
#   'is_2020': True},
#  {'slug': 'ognonnaz-1',
#   'location': 'Ognonnaz 1',
#   'latitude': '46.45994130',
#   'longitude': '6.85913410',
#   'city': 'Vevey',
#   'post': '1800',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Ognonnaz',
#   'city_slug': 'vevey',
#   'water_name_slug': 'ognonnaz',
#   'is_2020': False},
#  {'slug': 'oyonne',
#   'location': 'Oyonne',
#   'latitude': '46.45668200',
#   'longitude': '6.85226200',
#   'city': 'La Tour de Peilz',
#   'post': '1814',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'la-tour-de-peilz',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'parc-des-pierrettes',
#   'location': 'Parc des Pierrettes',
#   'latitude': '46.51521500',
#   'longitude': '6.57553100',
#   'city': 'Saint Sulpice',
#   'post': '1025',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'saint-sulpice',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'pfaffner_rothrist_ischik',
#   'location': 'Pfaffner_Rothrist_Ischik',
#   'latitude': '47.29856780',
#   'longitude': '7.89946640',
#   'city': 'Rothrist',
#   'post': '4852',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Pfaffnern',
#   'city_slug': 'rothrist',
#   'water_name_slug': 'pfaffnern',
#   'is_2020': False},
#  {'slug': 'pierrier-sud',
#   'location': 'Pierrier sud',
#   'latitude': '46.43956010',
#   'longitude': '6.89100010',
#   'city': 'Montreux',
#   'post': '1815',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'montreux',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'plage-de-cheyres',
#   'location': 'Plage de Cheyres',
#   'latitude': '46.81868900',
#   'longitude': '6.78225600',
#   'city': 'Cheyres',
#   'post': '1468',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Neuenburgersee',
#   'city_slug': 'cheyres',
#   'water_name_slug': 'neuenburgersee',
#   'is_2020': True},
#  {'slug': 'plage-de-dorigny',
#   'location': 'Plage de Dorigny',
#   'latitude': '46.51816900',
#   'longitude': '6.58331900',
#   'city': 'Saint Sulpice',
#   'post': '1025',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'saint-sulpice',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'plage-de-st-sulpice',
#   'location': 'Plage de St Sulpice',
#   'latitude': '46.51326500',
#   'longitude': '6.57097700',
#   'city': 'Saint Sulpice',
#   'post': '1025',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'saint-sulpice',
#   'water_name_slug': 'lac-leman',
#   'is_2020': True},
#  {'slug': 'preverenges',
#   'location': 'Préverenges',
#   'latitude': '46.51269000',
#   'longitude': '6.52765700',
#   'city': 'Préverenges',
#   'post': '1028',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'preverenges',
#   'water_name_slug': 'lac-leman',
#   'is_2020': True},
#  {'slug': 'quai-maria-belgia',
#   'location': 'Quai Maria Belgia',
#   'latitude': '46.46015600',
#   'longitude': '6.83671800',
#   'city': 'Vevey',
#   'post': '1800',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'vevey',
#   'water_name_slug': 'lac-leman',
#   'is_2020': True},
#  {'slug': 'rastplatz-stampf',
#   'location': 'Rastplatz Stampf',
#   'latitude': '47.21517700',
#   'longitude': '8.84428600',
#   'city': 'Jona city',
#   'post': '8645',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Zurichsee',
#   'city_slug': 'jona-city',
#   'water_name_slug': 'zurichsee',
#   'is_2020': True},
#  {'slug': 'reuss',
#   'location': 'Reuss',
#   'latitude': '47.32986910',
#   'longitude': '8.35684930',
#   'city': 'Bremgarten',
#   'post': '5626',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Reuss',
#   'city_slug': 'bremgarten',
#   'water_name_slug': 'reuss',
#   'is_2020': False},
#  {'slug': 'reuss_hunenberg_eberhardy',
#   'location': 'reuss_hünenberg_eberhardy',
#   'latitude': '47.23297550',
#   'longitude': '8.40101210',
#   'city': 'Hünenberg',
#   'post': '6331',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Reuss',
#   'city_slug': 'hunenberg',
#   'water_name_slug': 'reuss',
#   'is_2020': False},
#  {'slug': 'reuss_ottenbach_schoenenbergerl',
#   'location': 'reuss_ottenbach_schoenenbergerl',
#   'latitude': '47.27835450',
#   'longitude': '8.39422420',
#   'city': 'Merenschwand',
#   'post': '5634',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Reuss',
#   'city_slug': 'merenschwand',
#   'water_name_slug': 'reuss',
#   'is_2020': False},
#  {'slug': 'reuss_stkarli_linigersimhofy',
#   'location': 'Reuss_St.Karli_LinigerS/ImhofY',
#   'latitude': '47.05711180',
#   'longitude': '8.28791450',
#   'city': 'Luzern',
#   'post': '6004',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Reuss',
#   'city_slug': 'luzern',
#   'water_name_slug': 'reuss',
#   'is_2020': False},
#  {'slug': 'rhein-beach-tinguely',
#   'location': 'Rhein Beach Tinguely',
#   'latitude': '47.55864390',
#   'longitude': '7.61215360',
#   'city': 'Basel',
#   'post': '4058',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Rhein',
#   'city_slug': 'basel',
#   'water_name_slug': 'rhein',
#   'is_2020': False},
#  {'slug': 'rhein_basel',
#   'location': 'Rhein_Basel',
#   'latitude': '47.55680180',
#   'longitude': '7.60108560',
#   'city': 'Basel',
#   'post': '4058',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Rhein',
#   'city_slug': 'basel',
#   'water_name_slug': 'rhein',
#   'is_2020': False},
#  {'slug': 'rhein_basel_blarerp_1',
#   'location': 'Rhein_Basel_BlarerP_1',
#   'latitude': '47.58940620',
#   'longitude': '7.58731810',
#   'city': 'Huningue',
#   'post': '68330',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Rhein',
#   'city_slug': 'huningue',
#   'water_name_slug': 'rhein',
#   'is_2020': False},
#  {'slug': 'rhein_basel_blarerp_2',
#   'location': 'Rhein_Basel_BlarerP_2',
#   'latitude': '47.59115100',
#   'longitude': '7.58794850',
#   'city': 'Huningue',
#   'post': '68330',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Rhein',
#   'city_slug': 'huningue',
#   'water_name_slug': 'rhein',
#   'is_2020': False},
#  {'slug': 'rhein_basel_hungerbuehlern',
#   'location': 'Rhein_Basel_HungerbuehlerN',
#   'latitude': '47.55821760',
#   'longitude': '7.61034880',
#   'city': 'Basel',
#   'post': '4058',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Rhein',
#   'city_slug': 'basel',
#   'water_name_slug': 'rhein',
#   'is_2020': False},
#  {'slug': 'rhein_domatems_foppa_f',
#   'location': 'rhein_domatems_foppa_f',
#   'latitude': '46.83803750',
#   'longitude': '9.44763870',
#   'city': 'Domat Ems',
#   'post': '7013',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Rhein',
#   'city_slug': 'domat-ems',
#   'water_name_slug': 'rhein',
#   'is_2020': False},
#  {'slug': 'rhein_eglisau_gomringerp',
#   'location': 'rhein_eglisau_gomringerp',
#   'latitude': '47.57331590',
#   'longitude': '8.53458470',
#   'city': 'Eglisau',
#   'post': '8193',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Rhein',
#   'city_slug': 'eglisau',
#   'water_name_slug': 'rhein',
#   'is_2020': False},
#  {'slug': 'rhein_hemishofen_stolll',
#   'location': 'Rhein_Hemishofen_StollL',
#   'latitude': '47.67552360',
#   'longitude': '8.82802920',
#   'city': 'Hemishofen',
#   'post': '8261',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Rhein',
#   'city_slug': 'hemishofen',
#   'water_name_slug': 'rhein',
#   'is_2020': False},
#  {'slug': 'rhein_laag_jungbluthn',
#   'location': 'rhein_laag_jungbluthn',
#   'latitude': '47.69152540',
#   'longitude': '8.71721040',
#   'city': 'Büsingen a Hochrhein',
#   'post': '78266',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Rhein',
#   'city_slug': 'busingen-a-hochrhein',
#   'water_name_slug': 'rhein',
#   'is_2020': False},
#  {'slug': 'rolle-plage',
#   'location': 'Rolle-plage',
#   'latitude': '46.46130000',
#   'longitude': '6.34973900',
#   'city': 'Rolle',
#   'post': '1180',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'rolle',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'saint-sulpice',
#   'location': 'Saint Sulpice',
#   'latitude': '46.50780800',
#   'longitude': '6.54534400',
#   'city': 'Saint Sulpice',
#   'post': '1025',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'saint-sulpice',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'schiffenensee_duedingen_hirschij',
#   'location': 'schiffenensee_duedingen_hirschij',
#   'latitude': '46.85915140',
#   'longitude': '7.17643740',
#   'city': 'Düdingen',
#   'post': '3186',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Schiffenensee',
#   'city_slug': 'dudingen',
#   'water_name_slug': 'schiffenensee',
#   'is_2020': False},
#  {'slug': 'sempachersee_sempach_tampec',
#   'location': 'sempachersee_sempach_tampec',
#   'latitude': '47.12861810',
#   'longitude': '8.19187370',
#   'city': 'Sempach',
#   'post': '6204',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Sempachsee',
#   'city_slug': 'sempach',
#   'water_name_slug': 'sempachsee',
#   'is_2020': False},
#  {'slug': 'sense_torishaus_g-cubes',
#   'location': 'Sense_Törishaus_g cubes',
#   'latitude': '46.88312060',
#   'longitude': '7.35318890',
#   'city': 'Köniz',
#   'post': '3174',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Sense',
#   'city_slug': 'koniz',
#   'water_name_slug': 'sense',
#   'is_2020': False},
#  {'slug': 'sihlsee_einsiedeln_schilligerllacherl',
#   'location': 'sihlsee_einsiedeln_schilligerllacherl',
#   'latitude': '47.14139380',
#   'longitude': '8.76035880',
#   'city': 'Einsiedeln',
#   'post': '8840',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Sihlsee',
#   'city_slug': 'einsiedeln',
#   'water_name_slug': 'sihlsee',
#   'is_2020': False},
#  {'slug': 'sihl_adliswil_oggi_fort',
#   'location': 'Sihl_Adliswil_Oggi_Fort',
#   'latitude': '47.31242170',
#   'longitude': '8.52625490',
#   'city': 'Adliswil',
#   'post': '8134',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Sihl',
#   'city_slug': 'adliswil',
#   'water_name_slug': 'sihl',
#   'is_2020': False},
#  {'slug': 'sihl_horgen_bucherf',
#   'location': 'Sihl_Horgen_BucherF',
#   'latitude': '47.27269460',
#   'longitude': '8.55368210',
#   'city': 'Horgen',
#   'post': '8810',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Sihl',
#   'city_slug': 'horgen',
#   'water_name_slug': 'sihl',
#   'is_2020': False},
#  {'slug': 'sihl_leimbach_kruegerm',
#   'location': 'sihl_leimbach_kruegerm',
#   'latitude': '47.32543610',
#   'longitude': '8.51911950',
#   'city': 'Zurich',
#   'post': '8041',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Sihl',
#   'city_slug': 'zurich',
#   'water_name_slug': 'sihl',
#   'is_2020': False},
#  {'slug': 'sihl_menzingen_kucharska_magdalena',
#   'location': 'Sihl_Menzingen_Kucharska_Magdalena',
#   'latitude': '47.19150120',
#   'longitude': '8.61842140',
#   'city': 'Menzingen',
#   'post': '6313',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Sihl',
#   'city_slug': 'menzingen',
#   'water_name_slug': 'sihl',
#   'is_2020': False},
#  {'slug': 'sihl_zuerich_eggerskoehlingera',
#   'location': 'sihl_zuerich_eggerskoehlingera',
#   'latitude': '47.38189810',
#   'longitude': '8.53832790',
#   'city': 'Zurich',
#   'post': '8005',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Sihl',
#   'city_slug': 'zurich',
#   'water_name_slug': 'sihl',
#   'is_2020': False},
#  {'slug': 'sihl_zuerich_eichenbergerd',
#   'location': 'Sihl_zuerich_eichenbergerD',
#   'latitude': '47.33958830',
#   'longitude': '8.51669650',
#   'city': 'Zurich',
#   'post': '8041',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Sihl',
#   'city_slug': 'zurich',
#   'water_name_slug': 'sihl',
#   'is_2020': False},
#  {'slug': 'sihl_zuerich_scherfs',
#   'location': 'Sihl_Zuerich_ScherfS',
#   'latitude': '47.37314950',
#   'longitude': '8.53236980',
#   'city': 'Zurich',
#   'post': '8001',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Sihl',
#   'city_slug': 'zurich',
#   'water_name_slug': 'sihl',
#   'is_2020': False},
#  {'slug': 'sihl_zurich_himmelhebern',
#   'location': 'sihl_zurich_himmelhebern',
#   'latitude': '47.34305540',
#   'longitude': '8.51861220',
#   'city': 'Zurich',
#   'post': '8041',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Sihl',
#   'city_slug': 'zurich',
#   'water_name_slug': 'sihl',
#   'is_2020': False},
#  {'slug': 'sitter_gaiserwald_buehlerf',
#   'location': 'sitter_gaiserwald_buehlerf',
#   'latitude': '47.42516090',
#   'longitude': '9.34010370',
#   'city': 'St Gallen',
#   'post': '9000',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Sitter',
#   'city_slug': 'st-gallen',
#   'water_name_slug': 'sitter',
#   'is_2020': False},
#  {'slug': 'sitter_stgallen_jennya',
#   'location': 'Sitter_St.Gallen_JennyA',
#   'latitude': '47.41024240',
#   'longitude': '9.32037600',
#   'city': 'St Gallen',
#   'post': '9014',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Sitter',
#   'city_slug': 'st-gallen',
#   'water_name_slug': 'sitter',
#   'is_2020': False},
#  {'slug': 'sitter_stgallen_steinbrunnerf',
#   'location': 'sitter_stgallen_steinbrunnerf',
#   'latitude': '47.43329170',
#   'longitude': '9.35807470',
#   'city': 'St Gallen',
#   'post': '9000',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Sitter',
#   'city_slug': 'st-gallen',
#   'water_name_slug': 'sitter',
#   'is_2020': False},
#  {'slug': 'sorne_birse_wwfjura',
#   'location': 'sorne_birse_WWFJura',
#   'latitude': '47.37098680',
#   'longitude': '7.36090990',
#   'city': 'Delémont',
#   'post': '2800',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Birs',
#   'city_slug': 'delemont',
#   'water_name_slug': 'birs',
#   'is_2020': False},
#  {'slug': 'strandbeiz',
#   'location': 'Strandbeiz',
#   'latitude': '47.21586170',
#   'longitude': '8.84309840',
#   'city': 'Jona city',
#   'post': '8645',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Zurichsee',
#   'city_slug': 'jona-city',
#   'water_name_slug': 'zurichsee',
#   'is_2020': True},
#  {'slug': 'thunersee_spiez_meierd_1',
#   'location': 'thunersee_spiez_meierd_1',
#   'latitude': '46.70443680',
#   'longitude': '7.65788240',
#   'city': 'Spiez',
#   'post': '3646',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Thunersee',
#   'city_slug': 'spiez',
#   'water_name_slug': 'thunersee',
#   'is_2020': True},
#  {'slug': 'thur_schoenenberg_schaera',
#   'location': 'Thur_Schoenenberg_SchaerA',
#   'latitude': '47.52407260',
#   'longitude': '9.19833470',
#   'city': 'Kradolf Schönenberg',
#   'post': '9214',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Thur',
#   'city_slug': 'kradolf-schonenberg',
#   'water_name_slug': 'thur',
#   'is_2020': False},
#  {'slug': 'thur_schwarzenbach_meiliw',
#   'location': 'thur_schwarzenbach_meiliw',
#   'latitude': '47.44678660',
#   'longitude': '9.06381560',
#   'city': 'Wil',
#   'post': '9500',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Thur',
#   'city_slug': 'wil',
#   'water_name_slug': 'thur',
#   'is_2020': False},
#  {'slug': 'tiger-duck-beach',
#   'location': 'Tiger duck beach',
#   'latitude': '46.51825600',
#   'longitude': '6.58254600',
#   'city': 'Saint Sulpice',
#   'post': '1025',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'saint-sulpice',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'toss_bauma_kurthe',
#   'location': 'Töss_Bauma_KurthE',
#   'latitude': '47.37017570',
#   'longitude': '8.86782490',
#   'city': 'Bauma',
#   'post': '8494',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Töss',
#   'city_slug': 'bauma',
#   'water_name_slug': 'ti12ss',
#   'is_2020': False},
#  {'slug': 'toss_kollbrunn_burgid',
#   'location': 'töss_kollbrunn_bürgid',
#   'latitude': '47.45456980',
#   'longitude': '8.77968000',
#   'city': 'Zell',
#   'post': '8483',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Töss',
#   'city_slug': 'zell',
#   'water_name_slug': 'ti12ss',
#   'is_2020': False},
#  {'slug': 'toss_winterthur-2',
#   'location': 'Töss_Winterthur 2',
#   'latitude': '47.47870730',
#   'longitude': '8.70842640',
#   'city': 'Winterthur',
#   'post': '8406',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Töss',
#   'city_slug': 'winterthur',
#   'water_name_slug': 'ti12ss',
#   'is_2020': False},
#  {'slug': 'unterdsee_ermatingen_brunkem',
#   'location': 'unterdsee_ermatingen_brunkem',
#   'latitude': '47.67263330',
#   'longitude': '9.08124620',
#   'city': 'Ermatingen',
#   'post': '8272',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Untersee',
#   'city_slug': 'ermatingen',
#   'water_name_slug': 'untersee',
#   'is_2020': False},
#  {'slug': 'untersee_steckborn_siedlerm',
#   'location': 'untersee_steckborn_siedlerm',
#   'latitude': '48.49575410',
#   'longitude': '27.07421580',
#   'city': 'Selyshche',
#   'post': '60216',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Untersee',
#   'city_slug': 'selyshche',
#   'water_name_slug': 'untersee',
#   'is_2020': False},
#  {'slug': 'urnaesch_urnaesch_meierr',
#   'location': 'urnaesch_urnaesch_meierr',
#   'latitude': '47.32509860',
#   'longitude': '9.29541880',
#   'city': 'Hundwil',
#   'post': '9107',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Urnäsch',
#   'city_slug': 'hundwil',
#   'water_name_slug': 'urnasch',
#   'is_2020': False},
#  {'slug': 'versoix',
#   'location': 'Versoix',
#   'latitude': '46.28919400',
#   'longitude': '6.17056930',
#   'city': 'Versoix',
#   'post': '1290',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'versoix',
#   'water_name_slug': 'lac-leman',
#   'is_2020': True},
#  {'slug': 'veveyse',
#   'location': 'Veveyse',
#   'latitude': '46.46102200',
#   'longitude': '6.83498300',
#   'city': 'Vevey',
#   'post': '1800',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'vevey',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'vidy',
#   'location': 'Vidy',
#   'latitude': '46.51471550',
#   'longitude': '6.59858840',
#   'city': 'Lausanne',
#   'post': '1007',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'lausanne',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'vierwaldstattersee_weggis_schoberls_1',
#   'location': 'vierwaldstättersee_weggis_schöberls_1',
#   'latitude': '47.04453210',
#   'longitude': '8.41856890',
#   'city': 'Weggis',
#   'post': '6353',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Quatre Cantons',
#   'city_slug': 'weggis',
#   'water_name_slug': 'quatre-cantons',
#   'is_2020': False},
#  {'slug': 'vierwaldstattersee_weggis_schoberls_2',
#   'location': 'vierwaldstättersee_weggis_schöberls_2',
#   'latitude': '47.04395300',
#   'longitude': '8.41730760',
#   'city': 'Weggis',
#   'post': '6353',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Quatre Cantons',
#   'city_slug': 'weggis',
#   'water_name_slug': 'quatre-cantons',
#   'is_2020': False},
#  {'slug': 'vierwaldstattersee_weggis_schoberls_3',
#   'location': 'vierwaldstättersee_weggis_schöberls_3',
#   'latitude': '47.02995660',
#   'longitude': '8.41080100',
#   'city': 'Weggis',
#   'post': '6353',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Quatre Cantons',
#   'city_slug': 'weggis',
#   'water_name_slug': 'quatre-cantons',
#   'is_2020': False},
#  {'slug': 'villa-barton',
#   'location': 'Villa Barton',
#   'latitude': '46.22235000',
#   'longitude': '6.15250000',
#   'city': 'Genève',
#   'post': '1202',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lac Léman',
#   'city_slug': 'geneve',
#   'water_name_slug': 'lac-leman',
#   'is_2020': False},
#  {'slug': 'vira-gambarogno',
#   'location': 'Vira Gambarogno',
#   'latitude': '46.14356500',
#   'longitude': '8.83902500',
#   'city': 'Gambarogno',
#   'post': '6574',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Lago Maggiore',
#   'city_slug': 'gambarogno',
#   'water_name_slug': 'lago-maggiore',
#   'is_2020': True},
#  {'slug': 'vorderrhein_disentis_schmidn',
#   'location': 'vorderrhein_disentis_schmidn',
#   'latitude': '46.69827390',
#   'longitude': '8.85783730',
#   'city': 'Disentis Mustér',
#   'post': '7180',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Vorderrhein',
#   'city_slug': 'disentis-muster',
#   'water_name_slug': 'vorderrhein',
#   'is_2020': False},
#  {'slug': 'walensee_walenstadt_wysse',
#   'location': 'Walensee_Walenstadt_WyssE',
#   'latitude': '47.12182820',
#   'longitude': '9.29955170',
#   'city': 'Walenstadt',
#   'post': '8880',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Walensee',
#   'city_slug': 'walenstadt',
#   'water_name_slug': 'walensee',
#   'is_2020': True},
#  {'slug': 'weissenau-neuhaus',
#   'location': 'Weissenau-Neuhaus',
#   'latitude': '46.67658300',
#   'longitude': '7.81752800',
#   'city': 'Unterseen',
#   'post': '3800',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Thunersee',
#   'city_slug': 'unterseen',
#   'water_name_slug': 'thunersee',
#   'is_2020': True},
#  {'slug': 'zuerichsee_maennedorf_vanderkaadene',
#   'location': 'zuerichsee_maennedorf_vanderkaadene',
#   'latitude': '47.25475400',
#   'longitude': '8.68750380',
#   'city': 'Männedorf',
#   'post': '8708',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Zurichsee',
#   'city_slug': 'mannedorf',
#   'water_name_slug': 'zurichsee',
#   'is_2020': False},
#  {'slug': 'zuerichsee_richterswil_benkoem_2',
#   'location': 'zuerichsee_richterswil_benkoem_2',
#   'latitude': '47.21764580',
#   'longitude': '8.69871330',
#   'city': 'Richterswil',
#   'post': '8805',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Zurichsee',
#   'city_slug': 'richterswil',
#   'water_name_slug': 'zurichsee',
#   'is_2020': True},
#  {'slug': 'zuerichsee_staefa_hennm',
#   'location': 'zuerichsee_staefa_hennm',
#   'latitude': '47.23464310',
#   'longitude': '8.76988140',
#   'city': 'Stäfa',
#   'post': '8713',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Zurichsee',
#   'city_slug': 'stafa',
#   'water_name_slug': 'zurichsee',
#   'is_2020': False},
#  {'slug': 'zuerichsee_waedenswil_colomboc_1',
#   'location': 'zuerichsee_waedenswil_colomboc_1',
#   'latitude': '47.21954680',
#   'longitude': '8.69196110',
#   'city': 'Richterswil',
#   'post': '8805',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Zurichsee',
#   'city_slug': 'richterswil',
#   'water_name_slug': 'zurichsee',
#   'is_2020': False},
#  {'slug': 'zuerichsee_zurich_kullg',
#   'location': 'zuerichsee_zurich_kullg',
#   'latitude': '47.35395730',
#   'longitude': '8.55047430',
#   'city': 'Zurich',
#   'post': '8008',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Zurichsee',
#   'city_slug': 'zurich',
#   'water_name_slug': 'zurichsee',
#   'is_2020': False},
#  {'slug': 'zugerseecholler_cham_blarerm',
#   'location': 'ZugerseeCholler_Cham_BlarerM',
#   'latitude': '47.17821570',
#   'longitude': '8.48001280',
#   'city': 'Zug',
#   'post': '6300',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Zugersee',
#   'city_slug': 'zug',
#   'water_name_slug': 'zugersee',
#   'is_2020': False},
#  {'slug': 'zugersee_immensee_guedesd',
#   'location': 'zugersee_Immensee_Guedesd',
#   'latitude': '47.10668690',
#   'longitude': '8.47888120',
#   'city': 'Meierskappel',
#   'post': '6344',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Zugersee',
#   'city_slug': 'meierskappel',
#   'water_name_slug': 'zugersee',
#   'is_2020': False},
#  {'slug': 'zulg_steffisburg_schmassmanne',
#   'location': 'zulg_steffisburg_schmassmanne',
#   'latitude': '46.77424310',
#   'longitude': '7.62453720',
#   'city': 'Steffisburg',
#   'post': '3612',
#   'country': 'CH',
#   'water': 'r',
#   'water_name': 'Zulg',
#   'city_slug': 'steffisburg',
#   'water_name_slug': 'zulg',
#   'is_2020': False},
#  {'slug': 'zurichsee-feldeggstr-banningersand',
#   'location': 'Zürichsee Feldeggstr BänningerSand',
#   'latitude': '47.35939220',
#   'longitude': '8.54736820',
#   'city': 'Zurich',
#   'post': '8008',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Zurichsee',
#   'city_slug': 'zurich',
#   'water_name_slug': 'zurichsee',
#   'is_2020': False},
#  {'slug': 'zurichsee_kusnachterhorn_thirkell-whitej',
#   'location': 'Zürichsee_Küsnachterhorn_Thirkell WhiteJ',
#   'latitude': '47.31768490',
#   'longitude': '8.57686020',
#   'city': 'Küsnacht',
#   'post': '8700',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Zurichsee',
#   'city_slug': 'kusnacht',
#   'water_name_slug': 'zurichsee',
#   'is_2020': True},
#  {'slug': 'zurichsee_wollishofen_langendorfm',
#   'location': 'zürichsee_wollishofen_langendorfm',
#   'latitude': '47.34588990',
#   'longitude': '8.53615450',
#   'city': 'Zurich',
#   'post': '8038',
#   'country': 'CH',
#   'water': 'l',
#   'water_name': 'Zurichsee',
#   'city_slug': 'zurich',
#   'water_name_slug': 'zurichsee',
#   'is_2020': True}]
